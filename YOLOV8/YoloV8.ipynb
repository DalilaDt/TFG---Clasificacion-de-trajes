# %% [markdown]
# ### **Entrenamiento de Modelos de Clasificación de Imágenes YOLO V8**
#
# Autores:
# + Dalila Castelnovo
# + Sebastian Caballero

# %% [markdown]
# Entrenamiento del modelo 1

# %%
dataset_path = r'C:\\Users\\dalil\\Desktop\\Tesis_2025\\TFG---Clasificacion-de-trajes\\YOLOV8\\dataset'
model_out_path = r'C:\\Users\\dalil\\Desktop\\Tesis_2025\\TFG---Clasificacion-de-trajes\\YOLOV8\\modelo1'
# %cd {model_out_path}
# !yolo task=classify mode=train model=yolov8n-cls.pt data={dataset_path} epochs=20 imgsz=256
# Out:
# C:\Users\dalil\Desktop\Tesis_2025\Tutorial_yolo_\Tutorial_yolo\modelo2
# New https://pypi.org/project/ultralytics/8.3.76 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.67 🚀 Python-3.11.9 torch-2.5.1+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# ...

# %% [markdown]
# Entrenamiento del modelo 2

# %%
#Agregamos data argumentation
dataset_path = r'C:\\Users\\dalil\\Desktop\\Tesis_2025\\TFG---Clasificacion-de-trajes\\YOLOV8\\dataset'
model_out_path = r'C:\\Users\\dalil\\Desktop\\Tesis_2025\\TFG---Clasificacion-de-trajes\\YOLOV8\\modelo2'
# %cd {model_out_path}
# !yolo task=classify mode=train model=yolov8n-cls.pt data={dataset_path} epochs=20 imgsz=256 augment=True
# Out:
# C:\Users\dalil\Desktop\Tesis_2025\TFG---Clasificacion-de-trajes\YOLOV8\modelo2
# C:\Users\dalil\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
#
#   0%|          | 0.00/5.31M [00:00<?, ?B/s]
#   2%|▏         | 128k/5.31M [00:00<00:04, 1.10MB/s]
#   5%|▍         | 256k/5.31M [00:00<00:05, 1.01MB/s]
#   7%|▋         | 384k/5.31M [00:00<00:06, 799kB/s]
#   9%|▉         | 512k/5.31M [00:00<00:08, 609kB/s]
#  12%|█▏        | 640k/5.31M [00:00<00:08, 598kB/s]
#  14%|█▍        | 768k/5.31M [00:01<00:10, 434kB/s]
#  16%|█▋        | 896k/5.31M [00:02<00:14, 317kB/s]
#  19%|█▉        | 1.00M/5.31M [00:02<00:15, 293kB/s]
#  21%|██        | 1.12M/5.31M [00:03<00:16, 268kB/s]
#  24%|██▎       | 1.25M/5.31M [00:04<00:22, 191kB/s]
#  26%|██▌       | 1.38M/5.31M [00:05<00:25, 163kB/s]
# ...

# %% [markdown]
# Entrenamiento del modelo 3

# %%
#Usamos el optimizador AdamW
dataset_path = r'C:\\Users\\dalil\\Desktop\\Tesis_2025\\TFG---Clasificacion-de-trajes\\YOLOV8\\dataset'
model_out_path = r'C:\\Users\\dalil\\Desktop\\Tesis_2025\\TFG---Clasificacion-de-trajes\\YOLOV8\\modelo3'
# %cd {model_out_path}
# !yolo task=classify mode=train model=yolov8s-cls.pt data={dataset_path} epochs=50 imgsz=256 optimizer=AdamW
# Out:
# C:\Users\dalil\Desktop\Tesis_2025\Tutorial_yolo_\Tutorial_yolo\modelo6
# New https://pypi.org/project/ultralytics/8.3.91 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.67 🚀 Python-3.11.9 torch-2.5.1+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# ...

# %% [markdown]
# Entrenamiento del Modelo 4

# %%
#Ajustamos Learning Rate
dataset_path = r'C:\\Users\\dalil\\Desktop\\Tesis_2025\\TFG---Clasificacion-de-trajes\\YOLOV8\\dataset'
model_out_path = r'C:\\Users\\dalil\\Desktop\\Tesis_2025\\TFG---Clasificacion-de-trajes\\YOLOV8\\modelo4'
# %cd {model_out_path}!yolo task=classify mode=train model=yolov8s-cls.pt data={dataset_path} epochs=50 imgsz=256 lr0=0.001
# Out:
# [WinError 123] El nombre de archivo, el nombre de directorio o la sintaxis de la etiqueta del volumen no son correctos: 'C:\\\\Users\\\\dalil\\\\Desktop\\\\Tesis_2025\\\\Tutorial_yolo_\\\\Tutorial_yolo\\\\modelo7!yolo task=classify mode=train model=yolov8s-cls.pt data=C:\\\\Users\\\\dalil\\\\Desktop\\\\Tesis_2025\\\\Tutorial_yolo_\\\\Tutorial_yolo\\\\dataset epochs=50 imgsz=256 lr0=0.001'
# c:\Users\dalil\Desktop\Tesis_2025\Tutorial_yolo_\Tutorial_yolo

# %% [markdown]
# Entrenamiento del modelo 5

# %%
#Con YOLOV8M
from ultralytics import YOLO
model = YOLO('yolov8m-cls.pt')  # Versión M de YOLOv8 para clasificación
model.train(data=r"C:\Users\dalil\Desktop\Tesis_2025\Tutorial_yolo_\Tutorial_yolo\dataset",
            epochs=20, imgsz=256, project=r"C:\Users\dalil\Desktop\Tesis_2025\Tutorial_yolo_\Tutorial_yolo\modelo5")
# Out:
# ...
# 100%|██████████| 32.7M/32.7M [00:01<00:00, 26.1MB/s]
# New https://pypi.org/project/ultralytics/8.3.93 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.67  Python-3.11.9 torch-2.5.1+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# ...

# %% [markdown]
# Entrenamiento del Modelo 6

# %%
#Con yolo8m con hiperparametros

from ultralytics import YOLO

# Cargar el modelo YOLOv8 para clasificación
model = YOLO('yolov8m-cls.pt')

# Entrenamiento con hiperparámetros ajustados
model.train(
    data=r"C:\Users\dalil\Desktop\Tesis_2025\Tutorial_yolo_\Tutorial_yolo\dataset",
    epochs=20,  # Más épocas para mejor aprendizaje
    imgsz=256,  # Tamaño de la imagen
    batch=16,  # Tamaño del batch
    lr0=0.01,  # Tasa de aprendizaje inicial
    lrf=0.1,  # Factor de reducción de la tasa de aprendizaje
    momentum=0.9,  # Momento de optimización
    weight_decay=5e-4,  # Regularización L2
    optimizer='SGD',  # Optimizador (puede ser 'AdamW' también)
    project=r"C:\Users\dalil\Desktop\Tesis_2025\Tutorial_yolo_\Tutorial_yolo\modelo8m2",
    patience=10,  # Número de épocas sin mejora antes de detener el entrenamiento
    dropout=0.2,  # Tasa de dropout para prevenir overfitting
    augment=True  # Aumentación de datos
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.93 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.67  Python-3.11.9 torch-2.5.1+cpu CPU (11th Gen Intel Core(TM) i5-1135G7 2.40GHz)
# ...

# %% [markdown]
# Modelo 7

# %%
#Agregamos data argumentation
dataset_path = r'C:\\Users\\dalil\\Desktop\\Tesis_2025\\TFG---Clasificacion-de-trajes\\YOLOV8\\dataset'
model_out_path = r'C:\\Users\\dalil\\Desktop\\Tesis_2025\\TFG---Clasificacion-de-trajes\\YOLOV8\\modelo7'
# %cd {model_out_path}
# !yolo task=classify mode=train model=yolov8m-cls.pt data={dataset_path} epochs=20 imgsz=256 augment=True
# Out:
# [WinError 2] El sistema no puede encontrar el archivo especificado: 'C:\\\\Users\\\\dalil\\\\Desktop\\\\Tesis_2025\\\\TFG---Clasificacion-de-trajes\\\\YOLOV8\\\\modelo7'
# c:\Users\dalil\Desktop\Tesis_2025\TFG---Clasificacion-de-trajes\YOLOV8
# C:\Users\dalil\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
#
# train: Scanning C:\Users\dalil\Desktop\Tesis_2025\TFG---Clasificacion-de-trajes\YOLOV8\dataset\train... 1398 images, 0 corrupt: 100%|██████████| 1398/1398 [00:00<?, ?it/s]
# train: Scanning C:\Users\dalil\Desktop\Tesis_2025\TFG---Clasificacion-de-trajes\YOLOV8\dataset\train... 1398 images, 0 corrupt: 100%|██████████| 1398/1398 [00:00<?, ?it/s]
#
# ...
